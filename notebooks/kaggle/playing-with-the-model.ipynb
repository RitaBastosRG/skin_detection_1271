# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from tensorflow.keras.utils import img_to_array
from PIL import Image

# %%
import keras.backend as K

def f1_metric(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
import pickle
loaded_model = pickle.load(open('/kaggle/input/model-resnet/resnet_model_4.pkl', 'rb'))

# %%
img = Image.open("/kaggle/input/test2/download.jpg")
plt.imshow(img)

img_resize = img.resize((400, 400))
img = img_to_array(img_resize)
img=np.expand_dims(img, axis=0)

# %%
loaded_model.predict(img) ## BCC but predicted NV => WRONG

# %%
img2 = Image.open("/kaggle/input/bcc-2/bcc-1.jpg")
plt.imshow(img2)
img2_resize = img2.resize((400, 400))
img2 = img_to_array(img2_resize)
img2=np.expand_dims(img2, axis=0)

# %%
loaded_model.predict(img2) ## BCC and predicted BCC => CORRECT

# %%
img3 = Image.open("/kaggle/input/nv-img3/nv.jpg")
plt.imshow(img3)
img3_resize = img3.resize((400, 400))
img3 = img_to_array(img3_resize)
img3=np.expand_dims(img3, axis=0)

# %%
loaded_model.predict(img3) ## NV and predicted NV => CORRECT

# %%
img4 = Image.open("/kaggle/input/melanoma/melanomadark3.jpg")
plt.imshow(img4)
img4_resize = img4.resize((400, 400))
img4 = img_to_array(img4_resize)
img4=np.expand_dims(img4, axis=0)

# %%
loaded_model.predict(img4) ## almost the same probability...it is MEL so cancerous but predicted NV

# %%
img5 = Image.open("/kaggle/input/bccpicture/pigmented_basal2.png")
plt.imshow(img5)
img5_resize = img5.resize((400, 400))
img5 = img_to_array(img5_resize)
img5=np.expand_dims(img5, axis=0)

# %%
loaded_model.predict(img5) ## BCC and predicted BCC => CORRECT
